# %%
import pandas as pd
import numpy as np 
import warnings 
warnings.filterwarnings("ignore")
from sklearn import preprocessing

#load data into dataframes
xlsPath = r'C:\Users\New\Desktop\UniWork\ADA\ada2\final dataset.xlsx'
data = pd.read_excel(xlsPath)

attributes = data[['close','volume','etf close','s&p500 close',
                   '50 mda']]
class_var = data['price increase tomorrow?']

min_max_scaler = preprocessing.MinMaxScaler()
for column in attributes:
    attributes[column] = min_max_scaler.fit_transform(attributes[column].values.reshape(-1,1))

### Modify the split_number to change the train/test split. Use the first 1406 (which is 0.9*1562) for a 10% split.
split_number = 1406
train_attributes,train_class_var,test_attributes,test_class_var = \
attributes[:split_number],class_var[:split_number], \
attributes[split_number:],class_var[split_number:]

# %%
from keras import Sequential
from keras.layers import Embedding, LSTM, Dense, Dropout
from keras import metrics

model = Sequential()
model.add(Dense(64, input_dim=5, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'])

# %%
a = model.fit(train_attributes, train_class_var,
         epochs=100, verbose=0)

a = model.fit(train_attributes, train_class_var,
         epochs=10)
# Out:
# Epoch 1/10
# 1406/1406 [==============================] - 0s 36us/step - loss: 0.6879 - acc: 0.5413
# Epoch 2/10
# 1406/1406 [==============================] - 0s 36us/step - loss: 0.6909 - acc: 0.5427
# Epoch 3/10
# 1406/1406 [==============================] - 0s 36us/step - loss: 0.6855 - acc: 0.5477
# Epoch 4/10
# 1406/1406 [==============================] - 0s 35us/step - loss: 0.6869 - acc: 0.5420
# Epoch 5/10
# 1406/1406 [==============================] - 0s 36us/step - loss: 0.6874 - acc: 0.5533
# Epoch 6/10
# 1406/1406 [==============================] - 0s 40us/step - loss: 0.6923 - acc: 0.5384
# Epoch 7/10
# 1406/1406 [==============================] - 0s 48us/step - loss: 0.6878 - acc: 0.5491
# Epoch 8/10
# 1406/1406 [==============================] - 0s 42us/step - loss: 0.6888 - acc: 0.5370
# Epoch 9/10
# 1406/1406 [==============================] - 0s 36us/step - loss: 0.6886 - acc: 0.5299
# Epoch 10/10
# 1406/1406 [==============================] - 0s 35us/step - loss: 0.6926 - acc: 0.5505

# %%
score = model.evaluate(test_attributes,test_class_var)
print(score)
# Out:
# 156/156 [==============================] - 0s 32us/step
# [0.7279391242907598, 0.46794871871288007]

# %%
model.predict(test_attributes)
# Out:
# array([[ 0.51033086],
#        [ 0.50841343],
#        [ 0.50948614],
#        [ 0.50630039],
#        [ 0.50696683],
#        [ 0.51169664],
#        [ 0.5052529 ],
#        [ 0.50742197],
#        [ 0.50313908],
#        [ 0.50812662],
#        [ 0.5036149 ],
#        [ 0.50029558],
#        [ 0.49818283],
#        [ 0.49776354],
#        [ 0.50140744],
#        [ 0.50734657],
#        [ 0.50945127],
#        [ 0.50760227],
#        [ 0.50622451],
#        [ 0.50771457],
#        [ 0.51640618],
#        [ 0.51071656],
#        [ 0.51064885],
#        [ 0.51048702],
#        [ 0.509866  ],
#        [ 0.52106959],
#        [ 0.52038729],
#        [ 0.51881713],
#        [ 0.51686078],
#        [ 0.51683074],
#        [ 0.51483738],
#        [ 0.51604027],
#        [ 0.51657033],
#        [ 0.5150252 ],
#        [ 0.5141657 ],
#        [ 0.51154608],
#        [ 0.51028037],
#        [ 0.51107073],
#        [ 0.51394171],
#        [ 0.51169515],
#        [ 0.51216662],
#        [ 0.50731599],
#        [ 0.50442576],
#        [ 0.50849819],
#        [ 0.50531971],
#        [ 0.50949264],
#        [ 0.51319522],
#        [ 0.51712465],
#        [ 0.50391227],
#        [ 0.49710765],
#        [ 0.50120556],
#        [ 0.50084257],
#        [ 0.49721241],
#        [ 0.49341869],
#        [ 0.4975073 ],
#        [ 0.48957738],
#        [ 0.48607537],
#        [ 0.48604342],
#        [ 0.48695958],
#        [ 0.47871429],
#        [ 0.48138735],
#        [ 0.48746926],
#        [ 0.48201376],
#        [ 0.47746557],
#        [ 0.47659633],
#        [ 0.47836354],
#        [ 0.47170058],
#        [ 0.47477743],
#        [ 0.47501764],
#        [ 0.47726381],
#        [ 0.47509208],
#        [ 0.47566396],
#        [ 0.47872904],
#        [ 0.47531888],
#        [ 0.47354674],
#        [ 0.47183919],
#        [ 0.4811818 ],
#        [ 0.49085546],
#        [ 0.48983771],
#        [ 0.48552817],
#        [ 0.49408171],
#        [ 0.50799686],
#        [ 0.49806714],
#        [ 0.49330163],
#        [ 0.47380626],
#        [ 0.46542385],
#        [ 0.46477276],
#        [ 0.45869026],
#        [ 0.47612748],
#        [ 0.46055734],
#        [ 0.45368546],
#        [ 0.45560092],
#        [ 0.45975274],
#        [ 0.45903704],
#        [ 0.44757423],
#        [ 0.45309833],
#        [ 0.44458869],
#        [ 0.44888479],
#        [ 0.44537076],
#        [ 0.4506315 ],
#        [ 0.47098288],
#        [ 0.45308471],
#        [ 0.45254013],
#        [ 0.45160514],
#        [ 0.44364664],
#        [ 0.44147882],
#        [ 0.43691269],
#        [ 0.44157219],
#        [ 0.43960789],
#        [ 0.43562159],
#        [ 0.45376506],
#        [ 0.46803275],
#        [ 0.44520426],
#        [ 0.44714555],
#        [ 0.43876567],
#        [ 0.45372173],
#        [ 0.44461122],
#        [ 0.44679242],
#        [ 0.44993323],
#        [ 0.44654793],
#        [ 0.43911663],
#        [ 0.46741191],
#        [ 0.47440931],
#        [ 0.45603436],
#        [ 0.47407269],
#        [ 0.456191  ],
#        [ 0.47021925],
#        [ 0.44627643],
#        [ 0.44623038],
#        [ 0.44344985],
#        [ 0.44091782],
#        [ 0.44456843],
#        [ 0.43049338],
#        [ 0.44327778],
#        [ 0.44375986],
#        [ 0.45299634],
#        [ 0.46378329],
#        [ 0.4544479 ],
#        [ 0.45777425],
#        [ 0.45177028],
#        [ 0.45054263],
#        [ 0.44629619],
#        [ 0.45018449],
#        [ 0.44689524],
#        [ 0.45512292],
#        [ 0.44692832],
#        [ 0.45404282],
#        [ 0.45588845],
#        [ 0.4412545 ],
#        [ 0.4355205 ],
#        [ 0.43740338],
#        [ 0.44175908],
#        [ 0.43150789],
#        [ 0.43215081],
#        [ 0.43587637],
#        [ 0.43203476]], dtype=float32)
